# %%
# INFO 499
import pandas as pd
pd.options.mode.chained_assignment = None

#Read in data
# wk1Prior = pd.read_csv("CSV Files\wk1SeaPrior.csv")
wk2Prior = pd.read_csv("CSV Files\wk2SeaPrior.csv")
# wk3Prior = pd.read_csv("CSV Files\wk3SeaPrior.csv")

wk2Prior.head()
# Out:
#         Fields   Total Enough of the types of food wanted  \
# 0          NaN     NaN                                NaN
# 1        Total  77,676                             78,590
# 2         Age      NaN                                NaN
# 3      18 - 24       -                                  -
# 4      25 - 39  60,310                             53,120
#
#   Enough food, but not always the types wanted Sometimes not enough to eat  \
# 0                                          NaN                         NaN
# 1                                       30,645                       9,243
# 2                                          NaN                         NaN
# 3                                            -                           -
# 4                                       25,735                       8,145
#
#   Often not enough to eat Did not report
# 0                     NaN            NaN
# 1                  22,540            939
# ...

# %%
# Data Wrangling
def process_data(dataset, week):
    dataset = dataset.dropna(how='all')
    dataset['Fields'].str.replace(' ', '')
    dataset['Fields'] = week + dataset['Fields'].astype(str)
    return(dataset)

wk2Prior = process_data(wk2Prior, "wk2-")
# Out:
#                                                 Fields   Total  \
# 1                                            wk2-Total  77,676
# 2                                             wk2-Age      NaN
# 3                                      wk2-    18 - 24       -
# 4                                      wk2-    25 - 39  60,310
# 5                                      wk2-    40 - 54  41,750
# ..                                                 ...     ...
# 122  wk2-    Church, synagogue, temple, mosque or o...       -
# 123                    wk2-    Shelter or soup kitchen     386
# 124                    wk2-    Other community program  19,537
# 125              wk2-    Family, friends, or neighbors  18,908
# 126                             wk2-    Did not report  78,073
#
#     Enough of the types of food wanted  \
# 1                               78,590
# 2                                  NaN
# 3                                    -
# 4                               53,120
# ...
